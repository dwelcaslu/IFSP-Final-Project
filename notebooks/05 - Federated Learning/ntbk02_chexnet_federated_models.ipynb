# %%
import os, sys
sys.path.append('../../src')

from datetime import datetime
import pandas as pd

import visualization.visualize as vis
from data.load_dataset import load_dataset
from models.train_model import get_dataloaders, set_and_train_model
from models.model import get_model, evaluate_model, save_model
from federated.federated_learning import get_federated_avg_model

# %% [markdown]
# ## Running all databases and rounds

# %%
num_epochs = 5
base_path='../../models/federated_models/'

# %%
exec_time = datetime.now()
exec_id = f'{exec_time.year}-{exec_time.month}-{exec_time.day}_{exec_time.hour}h{exec_time.minute}m{exec_time.second}s'

training_stats = []
for round_number in [1,2,3,4,5]:
    model_id = f'fed_model_round{round_number}'
    model_id_old = f'fed_model_round{round_number-1}'
    model_name = f'{exec_id}_{model_id}'
    model_name_old = f'{exec_id}_{model_id_old}'
    local_models = []
    local_train_db_sizes = []

    for db_number in [1,2,3,4,5]:
        print(f'\n\nTraining round_number {round_number} db_number {db_number}:')
        df = load_dataset(db_number)
        dataloaders, db_sizes = get_dataloaders(df.sample(1000), round_number)

        ### Visualize a few images
        # Let's visualize a few training images so as to understand the data augmentations.
        # vis.plot_samples(dataloaders['train'], title=f'db_number {db_number} round_number {round_number} samples')        
        
        # Train the model
        model = get_model(model_name=model_name_old, base_path=base_path)
        model, model_hist = set_and_train_model(model, dataloaders, num_epochs=num_epochs)
        # vis.plot_model_hist(model_hist, f'Baseline Model db_number: {db_number} round_number: {round_number}')
        
        local_models.append(model)
        local_train_db_sizes.append(db_sizes['train'])
    
    fed_model = get_federated_avg_model(local_models, local_train_db_sizes)

    for db_number in [1,2,3,4,5]:
        print(f'\nEvaluating round_number {round_number} db_number {db_number}:')
        df = load_dataset(db_number)
        dataloaders, _ = get_dataloaders(df.sample(1000), round_number)

        # Evaluate model predictions
        model_stats = evaluate_model(fed_model, dataloaders, split='test')
        model_stats['round_number'] = round_number; model_stats['db_number'] = db_number
        training_stats.append(model_stats)

    # Saving current model:
    save_model(model, model_name, base_path=base_path)
# Out:
# Training round_number 1 db_number 1:
# train_set size: 236
# valid_set size: 74
# test_set size: 78
# total: 388
#
# File Not Found: 2022-10-9_17h30m59s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7066 Acc: 0.4746
# valid Loss: 0.7733 Acc: 0.4730
# 0m 7s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6336 Acc: 0.6483
# valid Loss: 0.7373 Acc: 0.5000
# 0m 5s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5285 Acc: 0.7754
# valid Loss: 0.7110 Acc: 0.6081
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4657 Acc: 0.7881
# valid Loss: 0.7788 Acc: 0.5676
# 0m 5s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3565 Acc: 0.8898
# valid Loss: 0.7238 Acc: 0.6216
# 0m 6s/epoch
# Training complete in 0m 30s
# Best val Acc: 0.621622
#
#
# Training round_number 1 db_number 2:
# train_set size: 224
# valid_set size: 70
# test_set size: 82
# total: 376
#
# File Not Found: 2022-10-9_17h30m59s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7294 Acc: 0.4955
# valid Loss: 0.6782 Acc: 0.5429
# 0m 5s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6227 Acc: 0.7009
# valid Loss: 0.6583 Acc: 0.5714
# 0m 5s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5663 Acc: 0.7232
# valid Loss: 0.6488 Acc: 0.6143
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4863 Acc: 0.7902
# valid Loss: 0.7438 Acc: 0.6000
# 0m 6s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4185 Acc: 0.8705
# valid Loss: 0.6640 Acc: 0.6286
# 0m 6s/epoch
# Training complete in 0m 27s
# Best val Acc: 0.628571
#
#
# Training round_number 1 db_number 3:
# train_set size: 256
# valid_set size: 69
# test_set size: 78
# total: 403
#
# File Not Found: 2022-10-9_17h30m59s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6928 Acc: 0.5469
# valid Loss: 0.6893 Acc: 0.5507
# 0m 7s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6327 Acc: 0.6289
# valid Loss: 0.6828 Acc: 0.5507
# 0m 6s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5333 Acc: 0.7500
# valid Loss: 0.7047 Acc: 0.5652
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4243 Acc: 0.8711
# valid Loss: 0.6933 Acc: 0.6812
# 0m 7s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3664 Acc: 0.8711
# valid Loss: 0.7069 Acc: 0.6667
# 0m 6s/epoch
# Training complete in 0m 32s
# Best val Acc: 0.681159
#
#
# Training round_number 1 db_number 4:
# train_set size: 233
# valid_set size: 69
# test_set size: 69
# total: 371
#
# File Not Found: 2022-10-9_17h30m59s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6808 Acc: 0.6137
# valid Loss: 0.6692 Acc: 0.6232
# 0m 6s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6245 Acc: 0.6438
# valid Loss: 0.7024 Acc: 0.6232
# 0m 6s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5953 Acc: 0.6867
# valid Loss: 0.6867 Acc: 0.6232
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.5320 Acc: 0.7425
# valid Loss: 0.6546 Acc: 0.6522
# 0m 6s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4305 Acc: 0.8155
# valid Loss: 0.6183 Acc: 0.6957
# 0m 7s/epoch
# Training complete in 0m 31s
# Best val Acc: 0.695652
#
#
# Training round_number 1 db_number 5:
# train_set size: 237
# valid_set size: 72
# test_set size: 99
# total: 408
#
# File Not Found: 2022-10-9_17h30m59s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6794 Acc: 0.5865
# valid Loss: 0.6412 Acc: 0.6667
# 0m 8s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6098 Acc: 0.7004
# valid Loss: 0.6100 Acc: 0.6667
# 0m 6s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5335 Acc: 0.7004
# valid Loss: 0.6260 Acc: 0.6250
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4555 Acc: 0.8228
# valid Loss: 0.6065 Acc: 0.6806
# 0m 8s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3843 Acc: 0.8650
# valid Loss: 0.6162 Acc: 0.6528
# 0m 6s/epoch
# Training complete in 0m 35s
# Best val Acc: 0.680556
# Cuda available: True. Model sent to device: cuda:0.
#
# Evaluating round_number 1 db_number 1:
# train_set size: 256
# valid_set size: 73
# test_set size: 70
# total: 399
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.47      1.00      0.64        33
#          1.0       0.00      0.00      0.00        37
#
#     accuracy                           0.47        70
#    macro avg       0.24      0.50      0.32        70
# weighted avg       0.22      0.47      0.30        70
#
#
# Evaluating round_number 1 db_number 2:
# train_set size: 244
# valid_set size: 69
# test_set size: 86
# total: 399
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.51      1.00      0.68        44
#          1.0       0.00      0.00      0.00        42
#
#     accuracy                           0.51        86
#    macro avg       0.26      0.50      0.34        86
# weighted avg       0.26      0.51      0.35        86
#
#
# Evaluating round_number 1 db_number 3:
# train_set size: 235
# valid_set size: 86
# test_set size: 76
# total: 397
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.75        46
#          1.0       0.00      0.00      0.00        30
#
#     accuracy                           0.61        76
#    macro avg       0.30      0.50      0.38        76
# weighted avg       0.37      0.61      0.46        76
#
#
# Evaluating round_number 1 db_number 4:
# train_set size: 244
# valid_set size: 78
# test_set size: 76
# total: 398
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70        41
#          1.0       0.00      0.00      0.00        35
#
#     accuracy                           0.54        76
#    macro avg       0.27      0.50      0.35        76
# weighted avg       0.29      0.54      0.38        76
#
#
# Evaluating round_number 1 db_number 5:
# train_set size: 210
# valid_set size: 79
# test_set size: 81
# total: 370
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74        48
#          1.0       0.00      0.00      0.00        33
#
#     accuracy                           0.59        81
#    macro avg       0.30      0.50      0.37        81
# weighted avg       0.35      0.59      0.44        81
#
# 2022-10-9_17h30m59s_fed_model_round1 saved at ../../models/federated_models/2022-10-9_17h30m59s_fed_model_round1.pth
#
#
# Training round_number 2 db_number 1:
# train_set size: 387
# valid_set size: 89
# test_set size: 105
# total: 581
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-9_17h30m59s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6952 Acc: 0.6021
# valid Loss: 0.6152 Acc: 0.6629
# 0m 11s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5454 Acc: 0.7468
# valid Loss: 0.6009 Acc: 0.7191
# 0m 10s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4519 Acc: 0.7984
# valid Loss: 0.5418 Acc: 0.7753
# 0m 10s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3596 Acc: 0.8579
# valid Loss: 0.5673 Acc: 0.7079
# 0m 10s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3507 Acc: 0.8630
# valid Loss: 0.6413 Acc: 0.6629
# 0m 10s/epoch
# Training complete in 0m 50s
# Best val Acc: 0.775281
#
#
# Training round_number 2 db_number 2:
# train_set size: 301
# valid_set size: 101
# test_set size: 131
# total: 533
#
# 2022-10-9_17h30m59s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6998 Acc: 0.5648
# valid Loss: 0.6222 Acc: 0.6634
# 0m 9s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6045 Acc: 0.6744
# valid Loss: 0.6027 Acc: 0.7129
# 0m 9s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5248 Acc: 0.7741
# valid Loss: 0.6183 Acc: 0.6139
# 0m 8s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4737 Acc: 0.7807
# valid Loss: 0.7971 Acc: 0.6139
# 0m 8s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3845 Acc: 0.8439
# valid Loss: 0.7193 Acc: 0.6040
# 0m 9s/epoch
# Training complete in 0m 43s
# Best val Acc: 0.712871
#
#
# Training round_number 2 db_number 3:
# train_set size: 333
# valid_set size: 105
# test_set size: 103
# total: 541
#
# 2022-10-9_17h30m59s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6175 Acc: 0.6517
# valid Loss: 0.7302 Acc: 0.6095
# 0m 10s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5303 Acc: 0.7417
# valid Loss: 0.8959 Acc: 0.5048
# 0m 10s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4035 Acc: 0.8198
# valid Loss: 0.7600 Acc: 0.5810
# 0m 9s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3239 Acc: 0.8889
# valid Loss: 0.7345 Acc: 0.6476
# 0m 10s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2464 Acc: 0.9189
# valid Loss: 0.8947 Acc: 0.5810
# 0m 10s/epoch
# Training complete in 0m 49s
# Best val Acc: 0.647619
#
#
# Training round_number 2 db_number 4:
# train_set size: 375
# valid_set size: 101
# test_set size: 84
# total: 560
#
# 2022-10-9_17h30m59s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7160 Acc: 0.5547
# valid Loss: 0.7241 Acc: 0.5050
# 0m 11s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6202 Acc: 0.6400
# valid Loss: 0.7389 Acc: 0.5149
# 0m 11s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5314 Acc: 0.7467
# valid Loss: 0.7003 Acc: 0.5644
# 0m 11s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4299 Acc: 0.8267
# valid Loss: 0.7128 Acc: 0.5743
# 0m 11s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3029 Acc: 0.9173
# valid Loss: 0.8078 Acc: 0.5842
# 0m 11s/epoch
# Training complete in 0m 55s
# Best val Acc: 0.584158
#
#
# Training round_number 2 db_number 5:
# train_set size: 333
# valid_set size: 105
# test_set size: 110
# total: 548
#
# 2022-10-9_17h30m59s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6658 Acc: 0.5886
# valid Loss: 0.6515 Acc: 0.6000
# 0m 11s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5445 Acc: 0.7237
# valid Loss: 0.6413 Acc: 0.6762
# 0m 10s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4527 Acc: 0.7868
# valid Loss: 0.6296 Acc: 0.6667
# 0m 10s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3307 Acc: 0.8949
# valid Loss: 0.6509 Acc: 0.6571
# 0m 10s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2584 Acc: 0.9099
# valid Loss: 0.6194 Acc: 0.7238
# 0m 11s/epoch
# Training complete in 0m 51s
# Best val Acc: 0.723810
# Cuda available: True. Model sent to device: cuda:0.
#
# Evaluating round_number 2 db_number 1:
# train_set size: 355
# valid_set size: 106
# test_set size: 96
# total: 557
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        60
#          1.0       0.00      0.00      0.00        36
#
#     accuracy                           0.62        96
#    macro avg       0.31      0.50      0.38        96
# weighted avg       0.39      0.62      0.48        96
#
#
# Evaluating round_number 2 db_number 2:
# train_set size: 307
# valid_set size: 110
# test_set size: 130
# total: 547
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.55      1.00      0.71        72
#          1.0       0.00      0.00      0.00        58
#
#     accuracy                           0.55       130
#    macro avg       0.28      0.50      0.36       130
# weighted avg       0.31      0.55      0.39       130
#
#
# Evaluating round_number 2 db_number 3:
# train_set size: 345
# valid_set size: 99
# test_set size: 114
# total: 558
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.72        64
#          1.0       0.00      0.00      0.00        50
#
#     accuracy                           0.56       114
#    macro avg       0.28      0.50      0.36       114
# weighted avg       0.32      0.56      0.40       114
#
#
# Evaluating round_number 2 db_number 4:
# train_set size: 339
# valid_set size: 105
# test_set size: 89
# total: 533
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.55      1.00      0.71        49
#          1.0       0.00      0.00      0.00        40
#
#     accuracy                           0.55        89
#    macro avg       0.28      0.50      0.36        89
# weighted avg       0.30      0.55      0.39        89
#
#
# Evaluating round_number 2 db_number 5:
# train_set size: 316
# valid_set size: 115
# test_set size: 120
# total: 551
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.56      1.00      0.72        67
#          1.0       0.00      0.00      0.00        53
#
#     accuracy                           0.56       120
#    macro avg       0.28      0.50      0.36       120
# weighted avg       0.31      0.56      0.40       120
#
# 2022-10-9_17h30m59s_fed_model_round2 saved at ../../models/federated_models/2022-10-9_17h30m59s_fed_model_round2.pth
#
#
# Training round_number 3 db_number 1:
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train_set size: 432
# valid_set size: 149
# test_set size: 128
# total: 709
#
# 2022-10-9_17h30m59s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7175 Acc: 0.6019
# valid Loss: 0.6213 Acc: 0.6846
# 0m 14s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5362 Acc: 0.7523
# valid Loss: 0.6715 Acc: 0.5503
# 0m 15s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4635 Acc: 0.7986
# valid Loss: 0.6057 Acc: 0.6443
# 0m 14s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2896 Acc: 0.9005
# valid Loss: 0.6305 Acc: 0.6510
# 0m 15s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2321 Acc: 0.9282
# valid Loss: 0.7023 Acc: 0.6711
# 0m 14s/epoch
# Training complete in 1m 12s
# Best val Acc: 0.684564
#
#
# Training round_number 3 db_number 2:
# train_set size: 439
# valid_set size: 140
# test_set size: 144
# total: 723
#
# 2022-10-9_17h30m59s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7488 Acc: 0.5831
# valid Loss: 0.6219 Acc: 0.6857
# 0m 17s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5594 Acc: 0.7221
# valid Loss: 0.6163 Acc: 0.6857
# 0m 17s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4510 Acc: 0.7995
# valid Loss: 0.6335 Acc: 0.6571
# 0m 17s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3190 Acc: 0.8838
# valid Loss: 0.6792 Acc: 0.6071
# 0m 15s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2082 Acc: 0.9431
# valid Loss: 0.7176 Acc: 0.6071
# 0m 14s/epoch
# Training complete in 1m 21s
# Best val Acc: 0.685714
#
#
# Training round_number 3 db_number 3:
# train_set size: 411
# valid_set size: 157
# test_set size: 154
# total: 722
#
# 2022-10-9_17h30m59s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7265 Acc: 0.6083
# valid Loss: 0.7491 Acc: 0.5350
# 0m 15s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5157 Acc: 0.7275
# valid Loss: 0.7167 Acc: 0.6051
# 0m 15s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4140 Acc: 0.8054
# valid Loss: 0.7498 Acc: 0.5732
# 0m 15s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2587 Acc: 0.9270
# valid Loss: 0.8487 Acc: 0.6306
# 0m 15s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2020 Acc: 0.9392
# valid Loss: 0.9780 Acc: 0.6051
# 0m 14s/epoch
# Training complete in 1m 13s
# Best val Acc: 0.630573
#
#
# Training round_number 3 db_number 4:
# train_set size: 446
# valid_set size: 130
# test_set size: 140
# total: 716
#
# 2022-10-9_17h30m59s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7186 Acc: 0.5874
# valid Loss: 0.6738 Acc: 0.5769
# 0m 14s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5372 Acc: 0.7242
# valid Loss: 0.7224 Acc: 0.6154
# 0m 14s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4160 Acc: 0.8251
# valid Loss: 0.7196 Acc: 0.5769
# 0m 14s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2954 Acc: 0.9058
# valid Loss: 0.7675 Acc: 0.6615
# 0m 14s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2063 Acc: 0.9439
# valid Loss: 0.9328 Acc: 0.6154
# 0m 15s/epoch
# Training complete in 1m 11s
# Best val Acc: 0.661538
#
#
# Training round_number 3 db_number 5:
# train_set size: 415
# valid_set size: 133
# test_set size: 154
# total: 702
#
# 2022-10-9_17h30m59s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7122 Acc: 0.6193
# valid Loss: 0.6534 Acc: 0.5940
# 0m 13s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5537 Acc: 0.7229
# valid Loss: 0.6563 Acc: 0.6692
# 0m 13s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4234 Acc: 0.8024
# valid Loss: 0.6964 Acc: 0.6090
# 0m 13s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3011 Acc: 0.9036
# valid Loss: 0.8113 Acc: 0.5639
# 0m 13s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2202 Acc: 0.9349
# valid Loss: 0.9552 Acc: 0.6391
# 0m 12s/epoch
# Training complete in 1m 5s
# Best val Acc: 0.669173
# Cuda available: True. Model sent to device: cuda:0.
#
# Evaluating round_number 3 db_number 1:
# train_set size: 456
# valid_set size: 101
# test_set size: 133
# total: 690
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.77        83
#          1.0       0.00      0.00      0.00        50
#
#     accuracy                           0.62       133
#    macro avg       0.31      0.50      0.38       133
# weighted avg       0.39      0.62      0.48       133
#
#
# Evaluating round_number 3 db_number 2:
# train_set size: 423
# valid_set size: 129
# test_set size: 157
# total: 709
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.53      1.00      0.69        83
#          1.0       0.00      0.00      0.00        74
#
#     accuracy                           0.53       157
#    macro avg       0.26      0.50      0.35       157
# weighted avg       0.28      0.53      0.37       157
#
#
# Evaluating round_number 3 db_number 3:
# train_set size: 445
# valid_set size: 134
# test_set size: 124
# total: 703
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70        67
#          1.0       0.00      0.00      0.00        57
#
#     accuracy                           0.54       124
#    macro avg       0.27      0.50      0.35       124
# weighted avg       0.29      0.54      0.38       124
#
#
# Evaluating round_number 3 db_number 4:
# train_set size: 411
# valid_set size: 139
# test_set size: 137
# total: 687
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.49      1.00      0.66        67
#          1.0       0.00      0.00      0.00        70
#
#     accuracy                           0.49       137
#    macro avg       0.24      0.50      0.33       137
# weighted avg       0.24      0.49      0.32       137
#
#
# Evaluating round_number 3 db_number 5:
# train_set size: 423
# valid_set size: 138
# test_set size: 156
# total: 717
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.47      1.00      0.64        73
#          1.0       0.00      0.00      0.00        83
#
#     accuracy                           0.47       156
#    macro avg       0.23      0.50      0.32       156
# weighted avg       0.22      0.47      0.30       156
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-9_17h30m59s_fed_model_round3 saved at ../../models/federated_models/2022-10-9_17h30m59s_fed_model_round3.pth
#
#
# Training round_number 4 db_number 1:
# train_set size: 533
# valid_set size: 149
# test_set size: 168
# total: 850
#
# 2022-10-9_17h30m59s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6677 Acc: 0.6154
# valid Loss: 0.8182 Acc: 0.5302
# 0m 17s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5260 Acc: 0.7317
# valid Loss: 0.7353 Acc: 0.5772
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4425 Acc: 0.8086
# valid Loss: 0.7524 Acc: 0.5906
# 0m 17s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3096 Acc: 0.8931
# valid Loss: 0.8321 Acc: 0.6040
# 0m 16s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2315 Acc: 0.9306
# valid Loss: 0.9283 Acc: 0.5302
# 0m 16s/epoch
# Training complete in 1m 23s
# Best val Acc: 0.604027
#
#
# Training round_number 4 db_number 2:
# train_set size: 492
# valid_set size: 171
# test_set size: 175
# total: 838
#
# 2022-10-9_17h30m59s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6671 Acc: 0.6341
# valid Loss: 0.6465 Acc: 0.6140
# 0m 17s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4854 Acc: 0.7683
# valid Loss: 0.6208 Acc: 0.6433
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3809 Acc: 0.8557
# valid Loss: 0.6122 Acc: 0.7018
# 0m 16s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2955 Acc: 0.8984
# valid Loss: 0.6828 Acc: 0.6550
# 0m 17s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2144 Acc: 0.9472
# valid Loss: 0.6689 Acc: 0.7135
# 0m 15s/epoch
# Training complete in 1m 21s
# Best val Acc: 0.713450
#
#
# Training round_number 4 db_number 3:
# train_set size: 504
# valid_set size: 172
# test_set size: 162
# total: 838
#
# 2022-10-9_17h30m59s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6369 Acc: 0.6687
# valid Loss: 0.6837 Acc: 0.5872
# 0m 17s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4962 Acc: 0.7738
# valid Loss: 0.7198 Acc: 0.6221
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3578 Acc: 0.8552
# valid Loss: 0.7013 Acc: 0.6512
# 0m 16s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2490 Acc: 0.9226
# valid Loss: 0.7884 Acc: 0.6512
# 0m 16s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1919 Acc: 0.9365
# valid Loss: 0.7989 Acc: 0.6744
# 0m 16s/epoch
# Training complete in 1m 22s
# Best val Acc: 0.674419
#
#
# Training round_number 4 db_number 4:
# train_set size: 537
# valid_set size: 149
# test_set size: 170
# total: 856
#
# 2022-10-9_17h30m59s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7493 Acc: 0.5754
# valid Loss: 0.6345 Acc: 0.5906
# 0m 15s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5839 Acc: 0.6927
# valid Loss: 0.6571 Acc: 0.6242
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4220 Acc: 0.8138
# valid Loss: 0.6712 Acc: 0.5906
# 0m 16s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3480 Acc: 0.8622
# valid Loss: 0.6866 Acc: 0.6242
# 0m 16s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2824 Acc: 0.8920
# valid Loss: 0.6644 Acc: 0.6510
# 0m 18s/epoch
# Training complete in 1m 21s
# Best val Acc: 0.651007
#
#
# Training round_number 4 db_number 5:
# train_set size: 512
# valid_set size: 156
# test_set size: 192
# total: 860
#
# 2022-10-9_17h30m59s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6900 Acc: 0.6367
# valid Loss: 0.7115 Acc: 0.5962
# 0m 17s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5693 Acc: 0.7090
# valid Loss: 0.7760 Acc: 0.6474
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4005 Acc: 0.8281
# valid Loss: 0.8002 Acc: 0.5897
# 0m 16s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2657 Acc: 0.9199
# valid Loss: 0.8749 Acc: 0.5577
# 0m 16s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2015 Acc: 0.9434
# valid Loss: 1.0435 Acc: 0.5833
# 0m 16s/epoch
# Training complete in 1m 22s
# Best val Acc: 0.647436
# Cuda available: True. Model sent to device: cuda:0.
#
# Evaluating round_number 4 db_number 1:
# train_set size: 514
# valid_set size: 160
# test_set size: 168
# total: 842
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.55      1.00      0.71        92
#          1.0       0.00      0.00      0.00        76
#
#     accuracy                           0.55       168
#    macro avg       0.27      0.50      0.35       168
# weighted avg       0.30      0.55      0.39       168
#
#
# Evaluating round_number 4 db_number 2:
# train_set size: 519
# valid_set size: 178
# test_set size: 170
# total: 867
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.48      1.00      0.65        81
#          1.0       0.00      0.00      0.00        89
#
#     accuracy                           0.48       170
#    macro avg       0.24      0.50      0.32       170
# weighted avg       0.23      0.48      0.31       170
#
#
# Evaluating round_number 4 db_number 3:
# train_set size: 467
# valid_set size: 204
# test_set size: 188
# total: 859
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.53      1.00      0.69        99
#          1.0       0.00      0.00      0.00        89
#
#     accuracy                           0.53       188
#    macro avg       0.26      0.50      0.34       188
# weighted avg       0.28      0.53      0.36       188
#
#
# Evaluating round_number 4 db_number 4:
# train_set size: 551
# valid_set size: 142
# test_set size: 183
# total: 876
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# valid_set size: 158
# test_set size: 181
# total: 842
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.57      1.00      0.73       104
#          1.0       0.00      0.00      0.00        77
#
#     accuracy                           0.57       181
#    macro avg       0.29      0.50      0.36       181
# weighted avg       0.33      0.57      0.42       181
#
# 2022-10-9_17h30m59s_fed_model_round4 saved at ../../models/federated_models/2022-10-9_17h30m59s_fed_model_round4.pth
#
#
# Training round_number 5 db_number 1:
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train_set size: 606
# valid_set size: 176
# test_set size: 218
# total: 1000
#
# 2022-10-9_17h30m59s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6784 Acc: 0.6370
# valid Loss: 0.5990 Acc: 0.6989
# 0m 19s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5354 Acc: 0.7327
# valid Loss: 0.5876 Acc: 0.7102
# 0m 20s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3950 Acc: 0.8284
# valid Loss: 0.6704 Acc: 0.7045
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3155 Acc: 0.8845
# valid Loss: 0.6904 Acc: 0.6534
# 0m 19s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2011 Acc: 0.9373
# valid Loss: 0.6413 Acc: 0.7330
# 0m 19s/epoch
# Training complete in 1m 36s
# Best val Acc: 0.732955
#
#
# Training round_number 5 db_number 2:
# train_set size: 563
# valid_set size: 212
# test_set size: 225
# total: 1000
#
# 2022-10-9_17h30m59s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6569 Acc: 0.6519
# valid Loss: 0.6248 Acc: 0.6509
# 0m 20s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5332 Acc: 0.7211
# valid Loss: 0.6536 Acc: 0.6557
# 0m 20s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3978 Acc: 0.8330
# valid Loss: 0.6627 Acc: 0.6557
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3182 Acc: 0.8792
# valid Loss: 0.6779 Acc: 0.6604
# 0m 23s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2349 Acc: 0.9041
# valid Loss: 0.7864 Acc: 0.6887
# 0m 23s/epoch
# Training complete in 1m 45s
# Best val Acc: 0.688679
#
#
# Training round_number 5 db_number 3:
# train_set size: 601
# valid_set size: 184
# test_set size: 215
# total: 1000
#
# 2022-10-9_17h30m59s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6502 Acc: 0.6589
# valid Loss: 0.7001 Acc: 0.6196
# 0m 20s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4626 Acc: 0.7870
# valid Loss: 0.7019 Acc: 0.6141
# 0m 21s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3509 Acc: 0.8636
# valid Loss: 0.7471 Acc: 0.6141
# 0m 21s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2473 Acc: 0.9085
# valid Loss: 0.8787 Acc: 0.5924
# 0m 21s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1702 Acc: 0.9501
# valid Loss: 0.9376 Acc: 0.5652
# 0m 21s/epoch
# Training complete in 1m 44s
# Best val Acc: 0.619565
#
#
# Training round_number 5 db_number 4:
# train_set size: 611
# valid_set size: 200
# test_set size: 189
# total: 1000
#
# 2022-10-9_17h30m59s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6640 Acc: 0.6367
# valid Loss: 0.6976 Acc: 0.6200
# 0m 22s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5487 Acc: 0.7234
# valid Loss: 0.7435 Acc: 0.6100
# 0m 20s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4166 Acc: 0.8298
# valid Loss: 0.7473 Acc: 0.6450
# 0m 20s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3442 Acc: 0.8691
# valid Loss: 0.8103 Acc: 0.6300
# 0m 21s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2649 Acc: 0.9018
# valid Loss: 0.8596 Acc: 0.6200
# 0m 21s/epoch
# Training complete in 1m 44s
# Best val Acc: 0.645000
#
#
# Training round_number 5 db_number 5:
# train_set size: 617
# valid_set size: 170
# test_set size: 213
# total: 1000
#
# 2022-10-9_17h30m59s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sent to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6700 Acc: 0.6370
# valid Loss: 0.6750 Acc: 0.6471
# 0m 19s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5271 Acc: 0.7569
# valid Loss: 0.6433 Acc: 0.6529
# 0m 19s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4181 Acc: 0.8233
# valid Loss: 0.6757 Acc: 0.6353
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2829 Acc: 0.9011
# valid Loss: 0.7085 Acc: 0.6471
# 0m 20s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1817 Acc: 0.9530
# valid Loss: 0.8212 Acc: 0.5824
# 0m 19s/epoch
# Training complete in 1m 36s
# Best val Acc: 0.652941
# Cuda available: True. Model sent to device: cuda:0.
#
# Evaluating round_number 5 db_number 1:
# train_set size: 625
# valid_set size: 189
# test_set size: 186
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.59      1.00      0.74       109
#          1.0       0.00      0.00      0.00        77
#
#     accuracy                           0.59       186
#    macro avg       0.29      0.50      0.37       186
# weighted avg       0.34      0.59      0.43       186
#
#
# Evaluating round_number 5 db_number 2:
# train_set size: 593
# valid_set size: 211
# test_set size: 196
# total: 1000
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70       106
#          1.0       0.00      0.00      0.00        90
#
#     accuracy                           0.54       196
#    macro avg       0.27      0.50      0.35       196
# weighted avg       0.29      0.54      0.38       196
#
#
# Evaluating round_number 5 db_number 3:
# train_set size: 596
# valid_set size: 203
# test_set size: 201
# total: 1000
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.49      1.00      0.66        98
#          1.0       0.00      0.00      0.00       103
#
#     accuracy                           0.49       201
#    macro avg       0.24      0.50      0.33       201
# weighted avg       0.24      0.49      0.32       201
#
#
# Evaluating round_number 5 db_number 4:
# train_set size: 610
# valid_set size: 194
# test_set size: 196
# total: 1000
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.47      1.00      0.64        93
#          1.0       0.00      0.00      0.00       103
#
#     accuracy                           0.47       196
#    macro avg       0.24      0.50      0.32       196
# weighted avg       0.23      0.47      0.31       196
#
#
# Evaluating round_number 5 db_number 5:
# train_set size: 600
# valid_set size: 182
# test_set size: 218
# total: 1000
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.49      1.00      0.65       106
#          1.0       0.00      0.00      0.00       112
#
#     accuracy                           0.49       218
#    macro avg       0.24      0.50      0.33       218
# weighted avg       0.24      0.49      0.32       218
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\weldl\Miniconda3\envs\federated\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-9_17h30m59s_fed_model_round5 saved at ../../models/federated_models/2022-10-9_17h30m59s_fed_model_round5.pth

# %%
# Saving statistics report:
training_stats = pd.DataFrame(training_stats)
training_stats.to_csv(f'{base_path}{exec_id}_training_stats.csv', index=False)

training_stats
# Out:
#     accuracy_score  balanced_accuracy_score  recall_score  precision_score  \
# 0         0.471429                      0.5           0.0              0.0
# 1         0.511628                      0.5           0.0              0.0
# 2         0.605263                      0.5           0.0              0.0
# 3         0.539474                      0.5           0.0              0.0
# 4         0.592593                      0.5           0.0              0.0
# 5         0.625000                      0.5           0.0              0.0
# 6         0.553846                      0.5           0.0              0.0
# 7         0.561404                      0.5           0.0              0.0
# 8         0.550562                      0.5           0.0              0.0
# 9         0.558333                      0.5           0.0              0.0
# 10        0.624060                      0.5           0.0              0.0
# 11        0.528662                      0.5           0.0              0.0
# 12        0.540323                      0.5           0.0              0.0
# 13        0.489051                      0.5           0.0              0.0
# 14        0.467949                      0.5           0.0              0.0
# 15        0.547619                      0.5           0.0              0.0
# 16        0.476471                      0.5           0.0              0.0
# 17        0.526596                      0.5           0.0              0.0
# 18        0.546448                      0.5           0.0              0.0
# 19        0.574586                      0.5           0.0              0.0
# 20        0.586022                      0.5           0.0              0.0
# 21        0.540816                      0.5           0.0              0.0
# 22        0.487562                      0.5           0.0              0.0
# 23        0.474490                      0.5           0.0              0.0
# 24        0.486239                      0.5           0.0              0.0
#
#     f1_score      confusion_matrix  round_number  db_number
# 0        0.0    [[33, 0], [37, 0]]             1          1
# 1        0.0    [[44, 0], [42, 0]]             1          2
# 2        0.0    [[46, 0], [30, 0]]             1          3
# 3        0.0    [[41, 0], [35, 0]]             1          4
# 4        0.0    [[48, 0], [33, 0]]             1          5
# 5        0.0    [[60, 0], [36, 0]]             2          1
# 6        0.0    [[72, 0], [58, 0]]             2          2
# 7        0.0    [[64, 0], [50, 0]]             2          3
# 8        0.0    [[49, 0], [40, 0]]             2          4
# 9        0.0    [[67, 0], [53, 0]]             2          5
# 10       0.0    [[83, 0], [50, 0]]             3          1
# 11       0.0    [[83, 0], [74, 0]]             3          2
# 12       0.0    [[67, 0], [57, 0]]             3          3
# 13       0.0    [[67, 0], [70, 0]]             3          4
# 14       0.0    [[73, 0], [83, 0]]             3          5
# 15       0.0    [[92, 0], [76, 0]]             4          1
# 16       0.0    [[81, 0], [89, 0]]             4          2
# 17       0.0    [[99, 0], [89, 0]]             4          3
# 18       0.0   [[100, 0], [83, 0]]             4          4
# 19       0.0   [[104, 0], [77, 0]]             4          5
# 20       0.0   [[109, 0], [77, 0]]             5          1
# 21       0.0   [[106, 0], [90, 0]]             5          2
# 22       0.0   [[98, 0], [103, 0]]             5          3
# 23       0.0   [[93, 0], [103, 0]]             5          4
# 24       0.0  [[106, 0], [112, 0]]             5          5

# %%
training_stats = pd.read_csv(f'{base_path}{exec_id}_training_stats.csv')
training_stats
# Out:
#     accuracy_score  balanced_accuracy_score  recall_score  precision_score  \
# 0         0.471429                      0.5           0.0              0.0
# 1         0.511628                      0.5           0.0              0.0
# 2         0.605263                      0.5           0.0              0.0
# 3         0.539474                      0.5           0.0              0.0
# 4         0.592593                      0.5           0.0              0.0
# 5         0.625000                      0.5           0.0              0.0
# 6         0.553846                      0.5           0.0              0.0
# 7         0.561404                      0.5           0.0              0.0
# 8         0.550562                      0.5           0.0              0.0
# 9         0.558333                      0.5           0.0              0.0
# 10        0.624060                      0.5           0.0              0.0
# 11        0.528662                      0.5           0.0              0.0
# 12        0.540323                      0.5           0.0              0.0
# 13        0.489051                      0.5           0.0              0.0
# 14        0.467949                      0.5           0.0              0.0
# 15        0.547619                      0.5           0.0              0.0
# 16        0.476471                      0.5           0.0              0.0
# 17        0.526596                      0.5           0.0              0.0
# 18        0.546448                      0.5           0.0              0.0
# 19        0.574586                      0.5           0.0              0.0
# 20        0.586022                      0.5           0.0              0.0
# 21        0.540816                      0.5           0.0              0.0
# 22        0.487562                      0.5           0.0              0.0
# 23        0.474490                      0.5           0.0              0.0
# 24        0.486239                      0.5           0.0              0.0
#
#     f1_score         confusion_matrix  round_number  db_number
# 0        0.0      [[33  0]\n [37  0]]             1          1
# 1        0.0      [[44  0]\n [42  0]]             1          2
# 2        0.0      [[46  0]\n [30  0]]             1          3
# 3        0.0      [[41  0]\n [35  0]]             1          4
# 4        0.0      [[48  0]\n [33  0]]             1          5
# 5        0.0      [[60  0]\n [36  0]]             2          1
# 6        0.0      [[72  0]\n [58  0]]             2          2
# 7        0.0      [[64  0]\n [50  0]]             2          3
# 8        0.0      [[49  0]\n [40  0]]             2          4
# 9        0.0      [[67  0]\n [53  0]]             2          5
# 10       0.0      [[83  0]\n [50  0]]             3          1
# 11       0.0      [[83  0]\n [74  0]]             3          2
# 12       0.0      [[67  0]\n [57  0]]             3          3
# 13       0.0      [[67  0]\n [70  0]]             3          4
# 14       0.0      [[73  0]\n [83  0]]             3          5
# 15       0.0      [[92  0]\n [76  0]]             4          1
# 16       0.0      [[81  0]\n [89  0]]             4          2
# 17       0.0      [[99  0]\n [89  0]]             4          3
# 18       0.0  [[100   0]\n [ 83   0]]             4          4
# 19       0.0  [[104   0]\n [ 77   0]]             4          5
# 20       0.0  [[109   0]\n [ 77   0]]             5          1
# 21       0.0  [[106   0]\n [ 90   0]]             5          2
# 22       0.0  [[ 98   0]\n [103   0]]             5          3
# 23       0.0  [[ 93   0]\n [103   0]]             5          4
# 24       0.0  [[106   0]\n [112   0]]             5          5
