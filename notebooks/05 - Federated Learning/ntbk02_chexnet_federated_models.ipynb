# %%
import os, sys
sys.path.append('../../src')

from datetime import datetime
import pandas as pd

import visualization.visualize as vis
from data.load_dataset import load_dataset
from models.train_model import get_dataloaders, set_and_train_model
from models.model import get_model, evaluate_model, save_model

# %% [markdown]
# ## Running all databases and rounds

# %%
num_epochs = 5
base_path='../../models/federated_models/'

# %%
def get_federated_model(local_models):
    key_select = list(local_models.keys())[0]
    return local_models[key_select]

# %%
exec_time = datetime.now()
exec_id = f'{exec_time.year}-{exec_time.month}-{exec_time.day}_{exec_time.hour}h{exec_time.minute}m{exec_time.second}s'

training_stats = []
for round_number in [1,2,3,4,5]:
    model_id = f'fed_model_round{round_number}'
    model_id_old = f'fed_model_round{round_number-1}'
    model_name = f'{exec_id}_{model_id}'
    model_name_old = f'{exec_id}_{model_id_old}'
    local_models = {}

    for db_number in [1,2,3,4,5]:
        print(f'\n\nTraining round_number {round_number} db_number {db_number}:')
        df = load_dataset(db_number)
        dataloaders = get_dataloaders(df.sample(1000), round_number)

        ### Visualize a few images
        # Let's visualize a few training images so as to understand the data augmentations.
        # vis.plot_samples(dataloaders['train'], title=f'db_number {db_number} round_number {round_number} samples')        
        
        # Train the model
        model = get_model(model_name=model_name_old, base_path=base_path)
        model, model_hist = set_and_train_model(model, dataloaders, num_epochs=num_epochs)
        # vis.plot_model_hist(model_hist, f'Baseline Model db_number: {db_number} round_number: {round_number}')
        
        local_models[model_name] = model
    
    fed_model = get_federated_model(local_models)

    for db_number in [1,2,3,4,5]:
        print(f'\nEvaluating round_number {round_number} db_number {db_number}:')
        df = load_dataset(db_number)
        dataloaders = get_dataloaders(df.sample(1000), round_number)

        # Evaluate model predictions
        model_stats = evaluate_model(fed_model, dataloaders, split='test')
        model_stats['round_number'] = round_number; model_stats['db_number'] = db_number
        training_stats.append(model_stats)

    # Saving current model:
    save_model(model, model_name, base_path=base_path)
# Out:
# Training round_number 1 db_number 1:
# train_set size: 228
# valid_set size: 90
# test_set size: 81
# total: 399
#
# File Not Found: 2022-10-6_0h10m24s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7005 Acc: 0.5088
# valid Loss: 0.6840 Acc: 0.5444
# 0m 9s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6440 Acc: 0.6184
# valid Loss: 0.6540 Acc: 0.6000
# 0m 6s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5878 Acc: 0.6623
# valid Loss: 0.6224 Acc: 0.6667
# 0m 6s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.5658 Acc: 0.7412
# valid Loss: 0.6833 Acc: 0.5000
# 0m 6s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4941 Acc: 0.7632
# valid Loss: 0.6857 Acc: 0.6222
# 0m 7s/epoch
# Training complete in 0m 37s
# Best val Acc: 0.666667
#
#
# Training round_number 1 db_number 2:
# train_set size: 235
# valid_set size: 76
# test_set size: 84
# total: 395
#
# File Not Found: 2022-10-6_0h10m24s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6813 Acc: 0.5489
# valid Loss: 0.6836 Acc: 0.5395
# 0m 6s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6036 Acc: 0.6936
# valid Loss: 0.6442 Acc: 0.6579
# 0m 7s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5221 Acc: 0.7532
# valid Loss: 0.6404 Acc: 0.6447
# 0m 7s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4561 Acc: 0.8085
# valid Loss: 0.6816 Acc: 0.6053
# 0m 7s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3647 Acc: 0.8723
# valid Loss: 0.6155 Acc: 0.6974
# 0m 7s/epoch
# Training complete in 0m 34s
# Best val Acc: 0.697368
#
#
# Training round_number 1 db_number 3:
# train_set size: 227
# valid_set size: 77
# test_set size: 81
# total: 385
#
# File Not Found: 2022-10-6_0h10m24s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7120 Acc: 0.4978
# valid Loss: 0.7042 Acc: 0.4545
# 0m 7s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6543 Acc: 0.6123
# valid Loss: 0.6511 Acc: 0.6104
# 0m 7s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5959 Acc: 0.7093
# valid Loss: 0.6392 Acc: 0.6104
# 0m 7s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.5289 Acc: 0.7709
# valid Loss: 0.6284 Acc: 0.6104
# 0m 6s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4733 Acc: 0.8150
# valid Loss: 0.6435 Acc: 0.6623
# 0m 6s/epoch
# Training complete in 0m 33s
# Best val Acc: 0.662338
#
#
# Training round_number 1 db_number 4:
# train_set size: 262
# valid_set size: 74
# test_set size: 81
# total: 417
#
# File Not Found: 2022-10-6_0h10m24s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6726 Acc: 0.6069
# valid Loss: 0.7072 Acc: 0.5946
# 0m 7s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6162 Acc: 0.6908
# valid Loss: 0.6936 Acc: 0.5946
# 0m 7s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5732 Acc: 0.7176
# valid Loss: 0.6937 Acc: 0.5676
# 0m 8s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.5195 Acc: 0.7748
# valid Loss: 0.7818 Acc: 0.5405
# 0m 7s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4581 Acc: 0.8092
# valid Loss: 0.8296 Acc: 0.5811
# 0m 7s/epoch
# Training complete in 0m 36s
# Best val Acc: 0.594595
#
#
# Training round_number 1 db_number 5:
# train_set size: 252
# valid_set size: 85
# test_set size: 74
# total: 411
#
# File Not Found: 2022-10-6_0h10m24s_fed_model_round0. Model will start with default initialization.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6613 Acc: 0.5913
# valid Loss: 0.6379 Acc: 0.6118
# 0m 8s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5832 Acc: 0.6905
# valid Loss: 0.6238 Acc: 0.6588
# 0m 7s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4941 Acc: 0.7976
# valid Loss: 0.6408 Acc: 0.6353
# 0m 8s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.4499 Acc: 0.8016
# valid Loss: 0.6961 Acc: 0.6706
# 0m 8s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.4186 Acc: 0.8254
# valid Loss: 0.6511 Acc: 0.6588
# 0m 8s/epoch
# Training complete in 0m 39s
# Best val Acc: 0.670588
#
# Evaluating round_number 1 db_number 1:
# train_set size: 258
# valid_set size: 58
# test_set size: 78
# total: 394
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.92      0.77        48
#          1.0       0.67      0.27      0.38        30
#
#     accuracy                           0.67        78
#    macro avg       0.67      0.59      0.58        78
# weighted avg       0.67      0.67      0.62        78
#
#
# Evaluating round_number 1 db_number 2:
# train_set size: 250
# valid_set size: 81
# test_set size: 83
# total: 414
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.98      0.71        43
#          1.0       0.88      0.17      0.29        40
#
#     accuracy                           0.59        83
#    macro avg       0.72      0.58      0.50        83
# weighted avg       0.71      0.59      0.51        83
#
#
# Evaluating round_number 1 db_number 3:
# train_set size: 240
# valid_set size: 63
# test_set size: 72
# total: 375
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.90      0.63        31
#          1.0       0.79      0.27      0.40        41
#
#     accuracy                           0.54        72
#    macro avg       0.63      0.59      0.51        72
# weighted avg       0.66      0.54      0.50        72
#
#
# Evaluating round_number 1 db_number 4:
# train_set size: 241
# valid_set size: 84
# test_set size: 75
# total: 400
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.93      0.76        42
#          1.0       0.80      0.36      0.50        33
#
#     accuracy                           0.68        75
#    macro avg       0.73      0.65      0.63        75
# weighted avg       0.72      0.68      0.65        75
#
#
# Evaluating round_number 1 db_number 5:
# train_set size: 236
# valid_set size: 66
# test_set size: 85
# total: 387
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.84      0.65        45
#          1.0       0.46      0.15      0.23        40
#
#     accuracy                           0.52        85
#    macro avg       0.49      0.50      0.44        85
# weighted avg       0.50      0.52      0.45        85
#
# 2022-10-6_0h10m24s_fed_model_round1 saved at ../../models/federated_models/2022-10-6_0h10m24s_fed_model_round1.pth
#
#
# Training round_number 2 db_number 1:
# train_set size: 332
# valid_set size: 97
# test_set size: 118
# total: 547
#
# 2022-10-6_0h10m24s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6925 Acc: 0.6114
# valid Loss: 0.6174 Acc: 0.6392
# 0m 10s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.6132 Acc: 0.6657
# valid Loss: 0.6319 Acc: 0.6392
# 0m 9s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5540 Acc: 0.7289
# valid Loss: 0.6574 Acc: 0.6495
# 0m 9s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3974 Acc: 0.8102
# valid Loss: 0.5866 Acc: 0.7113
# 0m 9s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2964 Acc: 0.8735
# valid Loss: 0.6270 Acc: 0.7010
# 0m 9s/epoch
# Training complete in 0m 47s
# Best val Acc: 0.711340
#
#
# Training round_number 2 db_number 2:
# train_set size: 347
# valid_set size: 101
# test_set size: 124
# total: 572
#
# 2022-10-6_0h10m24s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7072 Acc: 0.5879
# valid Loss: 0.6406 Acc: 0.6634
# 0m 11s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5377 Acc: 0.7579
# valid Loss: 0.6104 Acc: 0.6634
# 0m 10s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.5002 Acc: 0.7695
# valid Loss: 0.6754 Acc: 0.6139
# 0m 9s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3720 Acc: 0.8357
# valid Loss: 0.7157 Acc: 0.5941
# 0m 10s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2373 Acc: 0.9308
# valid Loss: 0.7828 Acc: 0.5545
# 0m 10s/epoch
# Training complete in 0m 49s
# Best val Acc: 0.663366
#
#
# Training round_number 2 db_number 3:
# train_set size: 361
# valid_set size: 109
# test_set size: 112
# total: 582
#
# 2022-10-6_0h10m24s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6268 Acc: 0.6316
# valid Loss: 0.6581 Acc: 0.6422
# 0m 11s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5053 Acc: 0.7756
# valid Loss: 0.6232 Acc: 0.6606
# 0m 10s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3876 Acc: 0.8421
# valid Loss: 0.7087 Acc: 0.6422
# 0m 14s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3005 Acc: 0.8864
# valid Loss: 0.7145 Acc: 0.6422
# 0m 15s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2363 Acc: 0.9169
# valid Loss: 0.7517 Acc: 0.6147
# 0m 15s/epoch
# Training complete in 1m 5s
# Best val Acc: 0.660550
#
#
# Training round_number 2 db_number 4:
# train_set size: 366
# valid_set size: 102
# test_set size: 91
# total: 559
#
# 2022-10-6_0h10m24s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6972 Acc: 0.5956
# valid Loss: 0.7130 Acc: 0.5294
# 0m 16s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5406 Acc: 0.7732
# valid Loss: 0.7388 Acc: 0.5588
# 0m 16s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4638 Acc: 0.8005
# valid Loss: 0.8186 Acc: 0.5686
# 0m 14s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3742 Acc: 0.8579
# valid Loss: 0.8250 Acc: 0.5588
# 0m 14s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3116 Acc: 0.8743
# valid Loss: 0.8785 Acc: 0.5686
# 0m 14s/epoch
# Training complete in 1m 15s
# Best val Acc: 0.568627
#
#
# Training round_number 2 db_number 5:
# train_set size: 336
# valid_set size: 89
# test_set size: 122
# total: 547
#
# 2022-10-6_0h10m24s_fed_model_round1.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6842 Acc: 0.6161
# valid Loss: 0.6609 Acc: 0.5843
# 0m 13s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5243 Acc: 0.7619
# valid Loss: 0.6526 Acc: 0.6292
# 0m 13s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4386 Acc: 0.8185
# valid Loss: 0.7137 Acc: 0.6180
# 0m 12s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3150 Acc: 0.8958
# valid Loss: 0.9522 Acc: 0.5955
# 0m 13s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2776 Acc: 0.8988
# valid Loss: 0.7972 Acc: 0.6180
# 0m 12s/epoch
# Training complete in 1m 3s
# Best val Acc: 0.629213
#
# Evaluating round_number 2 db_number 1:
# train_set size: 325
# valid_set size: 94
# test_set size: 136
# total: 555
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.68      0.68        78
#          1.0       0.57      0.57      0.57        58
#
#     accuracy                           0.63       136
#    macro avg       0.62      0.62      0.62       136
# weighted avg       0.63      0.63      0.63       136
#
#
# Evaluating round_number 2 db_number 2:
# train_set size: 330
# valid_set size: 115
# test_set size: 115
# total: 560
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.71      0.67        63
#          1.0       0.58      0.48      0.53        52
#
#     accuracy                           0.61       115
#    macro avg       0.60      0.60      0.60       115
# weighted avg       0.61      0.61      0.60       115
#
#
# Evaluating round_number 2 db_number 3:
# train_set size: 340
# valid_set size: 97
# test_set size: 118
# total: 555
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.77      0.76        73
#          1.0       0.60      0.58      0.59        45
#
#     accuracy                           0.69       118
#    macro avg       0.68      0.67      0.67       118
# weighted avg       0.69      0.69      0.69       118
#
#
# Evaluating round_number 2 db_number 4:
# train_set size: 338
# valid_set size: 105
# test_set size: 104
# total: 547
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.76      0.75        67
#          1.0       0.54      0.51      0.53        37
#
#     accuracy                           0.67       104
#    macro avg       0.64      0.64      0.64       104
# weighted avg       0.67      0.67      0.67       104
#
#
# Evaluating round_number 2 db_number 5:
# train_set size: 327
# valid_set size: 78
# test_set size: 125
# total: 530
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.76      0.73        72
#          1.0       0.63      0.55      0.59        53
#
#     accuracy                           0.67       125
#    macro avg       0.66      0.66      0.66       125
# weighted avg       0.67      0.67      0.67       125
#
# 2022-10-6_0h10m24s_fed_model_round2 saved at ../../models/federated_models/2022-10-6_0h10m24s_fed_model_round2.pth
#
#
# Training round_number 3 db_number 1:
# train_set size: 438
# valid_set size: 117
# test_set size: 132
# total: 687
#
# 2022-10-6_0h10m24s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6113 Acc: 0.6826
# valid Loss: 0.6139 Acc: 0.6410
# 0m 14s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5314 Acc: 0.7374
# valid Loss: 0.6845 Acc: 0.6154
# 0m 13s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4174 Acc: 0.8265
# valid Loss: 0.6598 Acc: 0.6581
# 0m 16s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3249 Acc: 0.8744
# valid Loss: 0.6302 Acc: 0.7009
# 0m 18s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2493 Acc: 0.9155
# valid Loss: 0.7103 Acc: 0.7009
# 0m 19s/epoch
# Training complete in 1m 20s
# Best val Acc: 0.700855
#
#
# Training round_number 3 db_number 2:
# train_set size: 373
# valid_set size: 151
# test_set size: 149
# total: 673
#
# 2022-10-6_0h10m24s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6465 Acc: 0.6595
# valid Loss: 0.7187 Acc: 0.6159
# 0m 20s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5414 Acc: 0.7131
# valid Loss: 0.7398 Acc: 0.6291
# 0m 19s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3929 Acc: 0.8365
# valid Loss: 0.7788 Acc: 0.6026
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3571 Acc: 0.8606
# valid Loss: 0.7875 Acc: 0.5762
# 0m 18s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2254 Acc: 0.9383
# valid Loss: 1.0025 Acc: 0.6026
# 0m 18s/epoch
# Training complete in 1m 34s
# Best val Acc: 0.629139
#
#
# Training round_number 3 db_number 3:
# train_set size: 422
# valid_set size: 128
# test_set size: 129
# total: 679
#
# 2022-10-6_0h10m24s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7091 Acc: 0.5806
# valid Loss: 0.7222 Acc: 0.5469
# 0m 18s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5412 Acc: 0.7370
# valid Loss: 0.6312 Acc: 0.6641
# 0m 17s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4605 Acc: 0.8104
# valid Loss: 0.6766 Acc: 0.6172
# 0m 17s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3707 Acc: 0.8436
# valid Loss: 0.6622 Acc: 0.6406
# 0m 17s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.3041 Acc: 0.8720
# valid Loss: 0.8324 Acc: 0.6172
# 0m 18s/epoch
# Training complete in 1m 26s
# Best val Acc: 0.664062
#
#
# Training round_number 3 db_number 4:
# train_set size: 452
# valid_set size: 116
# test_set size: 145
# total: 713
#
# 2022-10-6_0h10m24s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6688 Acc: 0.6128
# valid Loss: 0.6188 Acc: 0.6638
# 0m 18s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5485 Acc: 0.7279
# valid Loss: 0.6248 Acc: 0.6207
# 0m 14s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4423 Acc: 0.8053
# valid Loss: 0.6619 Acc: 0.6293
# 0m 14s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3633 Acc: 0.8473
# valid Loss: 0.9085 Acc: 0.5000
# 0m 21s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2406 Acc: 0.9314
# valid Loss: 0.6441 Acc: 0.6379
# 0m 16s/epoch
# Training complete in 1m 23s
# Best val Acc: 0.663793
#
#
# Training round_number 3 db_number 5:
# train_set size: 447
# valid_set size: 121
# test_set size: 150
# total: 718
#
# 2022-10-6_0h10m24s_fed_model_round2.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6128 Acc: 0.6779
# valid Loss: 0.6240 Acc: 0.6033
# 0m 16s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5025 Acc: 0.7517
# valid Loss: 0.7394 Acc: 0.6529
# 0m 15s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4372 Acc: 0.7897
# valid Loss: 0.7307 Acc: 0.6281
# 0m 17s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3054 Acc: 0.8926
# valid Loss: 0.7035 Acc: 0.6694
# 0m 23s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2545 Acc: 0.9195
# valid Loss: 0.7185 Acc: 0.6446
# 0m 25s/epoch
# Training complete in 1m 38s
# Best val Acc: 0.669421
#
# Evaluating round_number 3 db_number 1:
# train_set size: 422
# valid_set size: 125
# test_set size: 125
# total: 672
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.75      0.74        65
#          1.0       0.72      0.68      0.70        60
#
#     accuracy                           0.72       125
#    macro avg       0.72      0.72      0.72       125
# weighted avg       0.72      0.72      0.72       125
#
#
# Evaluating round_number 3 db_number 2:
# train_set size: 385
# valid_set size: 151
# test_set size: 151
# total: 687
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.65      0.63        78
#          1.0       0.59      0.53      0.56        73
#
#     accuracy                           0.60       151
#    macro avg       0.60      0.59      0.59       151
# weighted avg       0.60      0.60      0.59       151
#
#
# Evaluating round_number 3 db_number 3:
# train_set size: 430
# valid_set size: 128
# test_set size: 143
# total: 701
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.71      0.69        77
#          1.0       0.63      0.58      0.60        66
#
#     accuracy                           0.65       143
#    macro avg       0.65      0.65      0.65       143
# weighted avg       0.65      0.65      0.65       143
#
#
# Evaluating round_number 3 db_number 4:
# train_set size: 471
# valid_set size: 118
# test_set size: 118
# total: 707
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.77      0.59        44
#          1.0       0.79      0.50      0.61        74
#
#     accuracy                           0.60       118
#    macro avg       0.63      0.64      0.60       118
# weighted avg       0.67      0.60      0.60       118
#
#
# Evaluating round_number 3 db_number 5:
# train_set size: 375
# valid_set size: 132
# test_set size: 165
# total: 672
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.69      0.71        95
#          1.0       0.61      0.66      0.63        70
#
#     accuracy                           0.68       165
#    macro avg       0.67      0.68      0.67       165
# weighted avg       0.68      0.68      0.68       165
#
# 2022-10-6_0h10m24s_fed_model_round3 saved at ../../models/federated_models/2022-10-6_0h10m24s_fed_model_round3.pth
#
#
# Training round_number 4 db_number 1:
# train_set size: 548
# valid_set size: 140
# test_set size: 156
# total: 844
#
# 2022-10-6_0h10m24s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6673 Acc: 0.6314
# valid Loss: 0.7130 Acc: 0.6000
# 0m 22s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4943 Acc: 0.7719
# valid Loss: 0.6834 Acc: 0.6714
# 0m 18s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4063 Acc: 0.8321
# valid Loss: 0.7175 Acc: 0.6571
# 0m 17s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2878 Acc: 0.8923
# valid Loss: 0.7894 Acc: 0.6429
# 0m 17s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2511 Acc: 0.9051
# valid Loss: 1.0419 Acc: 0.5429
# 0m 18s/epoch
# Training complete in 1m 32s
# Best val Acc: 0.671429
#
#
# Training round_number 4 db_number 2:
# train_set size: 498
# valid_set size: 172
# test_set size: 167
# total: 837
#
# 2022-10-6_0h10m24s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7012 Acc: 0.6245
# valid Loss: 0.6655 Acc: 0.6279
# 0m 19s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5888 Acc: 0.6787
# valid Loss: 0.6893 Acc: 0.6337
# 0m 19s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4038 Acc: 0.8373
# valid Loss: 0.7134 Acc: 0.5872
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3360 Acc: 0.8614
# valid Loss: 0.8546 Acc: 0.6047
# 0m 23s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2421 Acc: 0.9197
# valid Loss: 0.7517 Acc: 0.6512
# 0m 23s/epoch
# Training complete in 1m 43s
# Best val Acc: 0.651163
#
#
# Training round_number 4 db_number 3:
# train_set size: 512
# valid_set size: 168
# test_set size: 150
# total: 830
#
# 2022-10-6_0h10m24s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6593 Acc: 0.6602
# valid Loss: 0.7452 Acc: 0.5714
# 0m 21s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5018 Acc: 0.7578
# valid Loss: 0.7081 Acc: 0.6310
# 0m 21s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3895 Acc: 0.8535
# valid Loss: 0.7266 Acc: 0.6667
# 0m 19s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2752 Acc: 0.8965
# valid Loss: 0.7497 Acc: 0.6548
# 0m 18s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1622 Acc: 0.9492
# valid Loss: 0.8041 Acc: 0.6607
# 0m 18s/epoch
# Training complete in 1m 36s
# Best val Acc: 0.666667
#
#
# Training round_number 4 db_number 4:
# train_set size: 538
# valid_set size: 146
# test_set size: 168
# total: 852
#
# 2022-10-6_0h10m24s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6686 Acc: 0.6636
# valid Loss: 0.6634 Acc: 0.6849
# 0m 18s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5390 Acc: 0.7454
# valid Loss: 0.5865 Acc: 0.7123
# 0m 18s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4476 Acc: 0.8086
# valid Loss: 0.6488 Acc: 0.6644
# 0m 18s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3333 Acc: 0.8680
# valid Loss: 0.6887 Acc: 0.6301
# 0m 19s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2455 Acc: 0.9052
# valid Loss: 0.7497 Acc: 0.7260
# 0m 21s/epoch
# Training complete in 1m 33s
# Best val Acc: 0.726027
#
#
# Training round_number 4 db_number 5:
# train_set size: 488
# valid_set size: 168
# test_set size: 188
# total: 844
#
# 2022-10-6_0h10m24s_fed_model_round3.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.6999 Acc: 0.6332
# valid Loss: 0.5842 Acc: 0.6905
# 0m 25s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5229 Acc: 0.7398
# valid Loss: 0.6088 Acc: 0.6786
# 0m 21s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4043 Acc: 0.8402
# valid Loss: 0.6208 Acc: 0.6726
# 0m 20s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2930 Acc: 0.8975
# valid Loss: 0.6037 Acc: 0.7024
# 0m 20s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2202 Acc: 0.9160
# valid Loss: 0.7297 Acc: 0.6786
# 0m 21s/epoch
# Training complete in 1m 47s
# Best val Acc: 0.702381
#
# Evaluating round_number 4 db_number 1:
# train_set size: 519
# valid_set size: 144
# test_set size: 176
# total: 839
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.86      0.76        95
#          1.0       0.77      0.53      0.63        81
#
#     accuracy                           0.71       176
#    macro avg       0.73      0.70      0.70       176
# weighted avg       0.72      0.71      0.70       176
#
#
# Evaluating round_number 4 db_number 2:
# train_set size: 486
# valid_set size: 187
# test_set size: 175
# total: 848
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.72      0.67        94
#          1.0       0.61      0.49      0.54        81
#
#     accuracy                           0.62       175
#    macro avg       0.61      0.61      0.61       175
# weighted avg       0.62      0.62      0.61       175
#
#
# Evaluating round_number 4 db_number 3:
# train_set size: 518
# valid_set size: 182
# test_set size: 162
# total: 862
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.84      0.75        89
#          1.0       0.72      0.49      0.59        73
#
#     accuracy                           0.69       162
#    macro avg       0.69      0.67      0.67       162
# weighted avg       0.69      0.69      0.67       162
#
#
# Evaluating round_number 4 db_number 4:
# train_set size: 546
# valid_set size: 140
# test_set size: 162
# total: 848
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.82      0.71        74
#          1.0       0.79      0.57      0.66        88
#
#     accuracy                           0.69       162
#    macro avg       0.70      0.70      0.68       162
# weighted avg       0.71      0.69      0.68       162
#
#
# Evaluating round_number 4 db_number 5:
# train_set size: 482
# valid_set size: 156
# test_set size: 207
# total: 845
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.70      0.63       108
#          1.0       0.57      0.43      0.49        99
#
#     accuracy                           0.57       207
#    macro avg       0.57      0.57      0.56       207
# weighted avg       0.57      0.57      0.57       207
#
# 2022-10-6_0h10m24s_fed_model_round4 saved at ../../models/federated_models/2022-10-6_0h10m24s_fed_model_round4.pth
#
#
# Training round_number 5 db_number 1:
# train_set size: 648
# valid_set size: 167
# test_set size: 185
# total: 1000
#
# 2022-10-6_0h10m24s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7151 Acc: 0.5957
# valid Loss: 0.6698 Acc: 0.6587
# 0m 25s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4931 Acc: 0.7562
# valid Loss: 0.6818 Acc: 0.6647
# 0m 23s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3697 Acc: 0.8410
# valid Loss: 0.7288 Acc: 0.7006
# 0m 21s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2748 Acc: 0.9028
# valid Loss: 0.7438 Acc: 0.6886
# 0m 21s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1879 Acc: 0.9306
# valid Loss: 0.8738 Acc: 0.6048
# 0m 21s/epoch
# Training complete in 1m 51s
# Best val Acc: 0.700599
#
#
# Training round_number 5 db_number 2:
# train_set size: 580
# valid_set size: 200
# test_set size: 220
# total: 1000
#
# 2022-10-6_0h10m24s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7192 Acc: 0.6414
# valid Loss: 0.6621 Acc: 0.6650
# 0m 27s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.4980 Acc: 0.7603
# valid Loss: 0.6597 Acc: 0.6850
# 0m 25s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3995 Acc: 0.8207
# valid Loss: 0.7267 Acc: 0.6300
# 0m 21s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2556 Acc: 0.9155
# valid Loss: 0.8017 Acc: 0.6350
# 0m 22s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2034 Acc: 0.9345
# valid Loss: 0.9405 Acc: 0.6300
# 0m 21s/epoch
# Training complete in 1m 56s
# Best val Acc: 0.685000
#
#
# Training round_number 5 db_number 3:
# train_set size: 611
# valid_set size: 201
# test_set size: 188
# total: 1000
#
# 2022-10-6_0h10m24s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7169 Acc: 0.6334
# valid Loss: 0.6356 Acc: 0.6567
# 0m 28s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5338 Acc: 0.7447
# valid Loss: 0.5888 Acc: 0.6816
# 0m 27s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3740 Acc: 0.8511
# valid Loss: 0.5617 Acc: 0.7214
# 0m 24s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2804 Acc: 0.8969
# valid Loss: 0.7165 Acc: 0.7214
# 0m 23s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2129 Acc: 0.9214
# valid Loss: 0.7228 Acc: 0.6766
# 0m 22s/epoch
# Training complete in 2m 4s
# Best val Acc: 0.721393
#
#
# Training round_number 5 db_number 4:
# train_set size: 616
# valid_set size: 191
# test_set size: 193
# total: 1000
#
# 2022-10-6_0h10m24s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7276 Acc: 0.6023
# valid Loss: 0.6478 Acc: 0.7016
# 0m 23s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5166 Acc: 0.7581
# valid Loss: 0.6471 Acc: 0.6963
# 0m 24s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.4151 Acc: 0.8198
# valid Loss: 0.6957 Acc: 0.6545
# 0m 23s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.3097 Acc: 0.8718
# valid Loss: 0.7053 Acc: 0.6545
# 0m 22s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.2063 Acc: 0.9286
# valid Loss: 0.8751 Acc: 0.6963
# 0m 25s/epoch
# Training complete in 1m 58s
# Best val Acc: 0.701571
#
#
# Training round_number 5 db_number 5:
# train_set size: 599
# valid_set size: 197
# test_set size: 204
# total: 1000
#
# 2022-10-6_0h10m24s_fed_model_round4.pth loaded successfully.
# Cuda available: True. Model sento to device: cuda:0.
#
# Epoch 0/4
# ----------
# train Loss: 0.7245 Acc: 0.6194
# valid Loss: 0.6302 Acc: 0.6497
# 0m 23s/epoch
#
# Epoch 1/4
# ----------
# train Loss: 0.5129 Acc: 0.7546
# valid Loss: 0.7334 Acc: 0.6244
# 0m 22s/epoch
#
# Epoch 2/4
# ----------
# train Loss: 0.3672 Acc: 0.8481
# valid Loss: 0.7192 Acc: 0.6041
# 0m 23s/epoch
#
# Epoch 3/4
# ----------
# train Loss: 0.2431 Acc: 0.9082
# valid Loss: 0.7712 Acc: 0.6396
# 0m 22s/epoch
#
# Epoch 4/4
# ----------
# train Loss: 0.1854 Acc: 0.9449
# valid Loss: 0.8912 Acc: 0.6142
# 0m 23s/epoch
# Training complete in 1m 54s
# Best val Acc: 0.649746
#
# Evaluating round_number 5 db_number 1:
# train_set size: 612
# valid_set size: 187
# test_set size: 201
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.76      0.65        98
#          1.0       0.66      0.46      0.54       103
#
#     accuracy                           0.60       201
#    macro avg       0.62      0.61      0.59       201
# weighted avg       0.62      0.60      0.59       201
#
#
# Evaluating round_number 5 db_number 2:
# train_set size: 594
# valid_set size: 210
# test_set size: 196
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.74      0.65        97
#          1.0       0.65      0.46      0.54        99
#
#     accuracy                           0.60       196
#    macro avg       0.61      0.60      0.59       196
# weighted avg       0.61      0.60      0.59       196
#
#
# Evaluating round_number 5 db_number 3:
# train_set size: 594
# valid_set size: 196
# test_set size: 210
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.67      0.64       114
#          1.0       0.55      0.49      0.52        96
#
#     accuracy                           0.59       210
#    macro avg       0.58      0.58      0.58       210
# weighted avg       0.58      0.59      0.58       210
#
#
# Evaluating round_number 5 db_number 4:
# train_set size: 612
# valid_set size: 190
# test_set size: 198
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.68      0.63       108
#          1.0       0.53      0.44      0.48        90
#
#     accuracy                           0.57       198
#    macro avg       0.56      0.56      0.56       198
# weighted avg       0.57      0.57      0.57       198
#
#
# Evaluating round_number 5 db_number 5:
# train_set size: 605
# valid_set size: 168
# test_set size: 227
# total: 1000
#
# Classification report for test set:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.75      0.67       112
#          1.0       0.68      0.52      0.59       115
#
#     accuracy                           0.63       227
#    macro avg       0.64      0.64      0.63       227
# weighted avg       0.64      0.63      0.63       227
#
# 2022-10-6_0h10m24s_fed_model_round5 saved at ../../models/federated_models/2022-10-6_0h10m24s_fed_model_round5.pth

# %%
# Saving statistics report:
training_stats = pd.DataFrame(training_stats)
training_stats.to_csv(f'{base_path}{exec_id}_training_stats.csv', index=False)

training_stats
# Out:
#     accuracy_score  balanced_accuracy_score  recall_score  precision_score  \
# 0         0.666667                 0.591667      0.266667         0.666667
# 1         0.590361                 0.575872      0.175000         0.875000
# 2         0.541667                 0.585759      0.268293         0.785714
# 3         0.680000                 0.646104      0.363636         0.800000
# 4         0.517647                 0.497222      0.150000         0.461538
# 5         0.632353                 0.624226      0.568966         0.568966
# 6         0.608696                 0.597527      0.480769         0.581395
# 7         0.694915                 0.672451      0.577778         0.604651
# 8         0.673077                 0.637354      0.513514         0.542857
# 9         0.672000                 0.655529      0.547170         0.630435
# 10        0.720000                 0.718590      0.683333         0.719298
# 11        0.596026                 0.594046      0.534247         0.590909
# 12        0.650350                 0.645022      0.575758         0.633333
# 13        0.601695                 0.636364      0.500000         0.787234
# 14        0.678788                 0.675940      0.657143         0.613333
# 15        0.710227                 0.697011      0.530864         0.767857
# 16        0.617143                 0.608616      0.493827         0.606061
# 17        0.685185                 0.667924      0.493151         0.720000
# 18        0.685185                 0.696253      0.568182         0.793651
# 19        0.574879                 0.569024      0.434343         0.573333
# 20        0.601990                 0.605706      0.456311         0.661972
# 21        0.602041                 0.603457      0.464646         0.647887
# 22        0.585714                 0.578125      0.489583         0.552941
# 23        0.570707                 0.560185      0.444444         0.533333
# 24        0.634361                 0.635870      0.521739         0.681818
#
#     f1_score      confusion_matrix  round_number  db_number
# 0   0.380952    [[44, 4], [22, 8]]             1          1
# 1   0.291667    [[42, 1], [33, 7]]             1          2
# 2   0.400000   [[28, 3], [30, 11]]             1          3
# 3   0.500000   [[39, 3], [21, 12]]             1          4
# 4   0.226415    [[38, 7], [34, 6]]             1          5
# 5   0.568966  [[53, 25], [25, 33]]             2          1
# 6   0.526316  [[45, 18], [27, 25]]             2          2
# 7   0.590909  [[56, 17], [19, 26]]             2          3
# 8   0.527778  [[51, 16], [18, 19]]             2          4
# 9   0.585859  [[55, 17], [24, 29]]             2          5
# 10  0.700855  [[49, 16], [19, 41]]             3          1
# 11  0.561151  [[51, 27], [34, 39]]             3          2
# 12  0.603175  [[55, 22], [28, 38]]             3          3
# 13  0.611570  [[34, 10], [37, 37]]             3          4
# 14  0.634483  [[66, 29], [24, 46]]             3          5
# 15  0.627737  [[82, 13], [38, 43]]             4          1
# 16  0.544218  [[68, 26], [41, 40]]             4          2
# 17  0.585366  [[75, 14], [37, 36]]             4          3
# 18  0.662252  [[61, 13], [38, 50]]             4          4
# 19  0.494253  [[76, 32], [56, 43]]             4          5
# 20  0.540230  [[74, 24], [56, 47]]             5          1
# 21  0.541176  [[72, 25], [53, 46]]             5          2
# 22  0.519337  [[76, 38], [49, 47]]             5          3
# 23  0.484848  [[73, 35], [50, 40]]             5          4
# 24  0.591133  [[84, 28], [55, 60]]             5          5

# %%
training_stats = pd.read_csv(f'{base_path}{exec_id}_training_stats.csv')
training_stats
# Out:
#     accuracy_score  balanced_accuracy_score  recall_score  precision_score  \
# 0         0.666667                 0.591667      0.266667         0.666667
# 1         0.590361                 0.575872      0.175000         0.875000
# 2         0.541667                 0.585759      0.268293         0.785714
# 3         0.680000                 0.646104      0.363636         0.800000
# 4         0.517647                 0.497222      0.150000         0.461538
# 5         0.632353                 0.624226      0.568966         0.568966
# 6         0.608696                 0.597527      0.480769         0.581395
# 7         0.694915                 0.672451      0.577778         0.604651
# 8         0.673077                 0.637354      0.513514         0.542857
# 9         0.672000                 0.655529      0.547170         0.630435
# 10        0.720000                 0.718590      0.683333         0.719298
# 11        0.596026                 0.594046      0.534247         0.590909
# 12        0.650350                 0.645022      0.575758         0.633333
# 13        0.601695                 0.636364      0.500000         0.787234
# 14        0.678788                 0.675940      0.657143         0.613333
# 15        0.710227                 0.697011      0.530864         0.767857
# 16        0.617143                 0.608616      0.493827         0.606061
# 17        0.685185                 0.667924      0.493151         0.720000
# 18        0.685185                 0.696253      0.568182         0.793651
# 19        0.574879                 0.569024      0.434343         0.573333
# 20        0.601990                 0.605706      0.456311         0.661972
# 21        0.602041                 0.603457      0.464646         0.647887
# 22        0.585714                 0.578125      0.489583         0.552941
# 23        0.570707                 0.560185      0.444444         0.533333
# 24        0.634361                 0.635870      0.521739         0.681818
#
#     f1_score     confusion_matrix  round_number  db_number
# 0   0.380952  [[44  4]\n [22  8]]             1          1
# 1   0.291667  [[42  1]\n [33  7]]             1          2
# 2   0.400000  [[28  3]\n [30 11]]             1          3
# 3   0.500000  [[39  3]\n [21 12]]             1          4
# 4   0.226415  [[38  7]\n [34  6]]             1          5
# 5   0.568966  [[53 25]\n [25 33]]             2          1
# 6   0.526316  [[45 18]\n [27 25]]             2          2
# 7   0.590909  [[56 17]\n [19 26]]             2          3
# 8   0.527778  [[51 16]\n [18 19]]             2          4
# 9   0.585859  [[55 17]\n [24 29]]             2          5
# 10  0.700855  [[49 16]\n [19 41]]             3          1
# 11  0.561151  [[51 27]\n [34 39]]             3          2
# 12  0.603175  [[55 22]\n [28 38]]             3          3
# 13  0.611570  [[34 10]\n [37 37]]             3          4
# 14  0.634483  [[66 29]\n [24 46]]             3          5
# 15  0.627737  [[82 13]\n [38 43]]             4          1
# 16  0.544218  [[68 26]\n [41 40]]             4          2
# 17  0.585366  [[75 14]\n [37 36]]             4          3
# 18  0.662252  [[61 13]\n [38 50]]             4          4
# 19  0.494253  [[76 32]\n [56 43]]             4          5
# 20  0.540230  [[74 24]\n [56 47]]             5          1
# 21  0.541176  [[72 25]\n [53 46]]             5          2
# 22  0.519337  [[76 38]\n [49 47]]             5          3
# 23  0.484848  [[73 35]\n [50 40]]             5          4
# 24  0.591133  [[84 28]\n [55 60]]             5          5
